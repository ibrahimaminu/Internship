# %%
# !pip install bs4
# !pip install requests
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=fe7f172003d60612bcd8cebd99a8522e17fbe434e384d3d274754d6620e99efe
#   Stored in directory: /Users/ibrahim/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...

# %%
# Importing Required Libraries
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Send Request

# %%
page = requests.get('https://en.m.wikipedia.org/wiki/Main_Page')

# %%
page
# Out:
# <Response [200]>

# %%
# Download Page Content

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...
